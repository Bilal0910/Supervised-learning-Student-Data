# %% [markdown]
# GRIP TASK # 01 : DATA SCIENCE AND BUSINESS ANALYTICS

# %% [markdown]
# TASK : PREDICTING STUDENTS SCORE BASED ON THEIR NUMBERS

# %% [markdown]
# IMPORTING THE REQUIRED LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# FETCHING DATA AND PRESENTING IT IN A DATAFRAME

# %%
url = "https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
dataset = pd.read_csv(url)
print(dataset)
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %% [markdown]
# DATASET INFORMATION

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes
# None

# %% [markdown]
# HEAD OF THE DATASET

# %%
print(dataset.head())
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# TAIL OF THE DATASET

# %%
print(dataset.tail())
# Out:
#     Hours  Scores
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %% [markdown]
# DESCRIBING VARIOUS PROPERITES OF DATA

# %%
print(dataset.describe())
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# CHECKING IF THERE IS ANY NULL VALUE IN DATA

# %%
print(dataset.isnull())
# Out:
#     Hours  Scores
# 0   False   False
# 1   False   False
# 2   False   False
# 3   False   False
# 4   False   False
# 5   False   False
# 6   False   False
# 7   False   False
# 8   False   False
# 9   False   False
# 10  False   False
# 11  False   False
# 12  False   False
# 13  False   False
# 14  False   False
# 15  False   False
# 16  False   False
# 17  False   False
# 18  False   False
# 19  False   False
# 20  False   False
# 21  False   False
# 22  False   False
# 23  False   False
# 24  False   False

# %% [markdown]
# SUM OF THE NULL VALUES IN DATA IF THERE'S ANY

# %%
print(dataset.isna().sum())
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# PLOTTING WITH SEABORN (SCORES OVER HOURS)

# %%
sns.regplot(x="Hours", y="Scores", data=dataset)
plt.grid(True, linestyle="-.", color="red")

# %% [markdown]
# CORRELATION OF DATA AND VISUALIZING DATA IN A HEATMAP

# %%
correlation = dataset.corr()
sns.heatmap(correlation, annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# SEPERATING DATA FOR HOURS AND SCORES

# %%
x= dataset.iloc[:, :1].values
y= dataset.iloc[:, 1:].values
print(x)
print(y)
# Out:
# [[2.5]
#  [5.1]
#  [3.2]
#  [8.5]
#  [3.5]
#  [1.5]
#  [9.2]
#  [5.5]
#  [8.3]
#  [2.7]
#  [7.7]
#  [5.9]
#  [4.5]
#  [3.3]
#  [1.1]
#  [8.9]
#  [2.5]
#  [1.9]
#  [6.1]
#  [7.4]
#  [2.7]
#  [4.8]
#  [3.8]
#  [6.9]
#  [7.8]]
# [[21]
#  [47]
#  [27]
#  [75]
#  [30]
#  [20]
#  [88]
#  [60]
#  [81]
#  [25]
#  [85]
#  [62]
#  [41]
#  [42]
#  [17]
#  [95]
#  [30]
#  [24]
#  [67]
#  [69]
#  [30]
#  [54]
#  [35]
#  [76]
#  [86]]

# %% [markdown]
# PLOTTING HOURS VS SCORES OF A STUDENT WITH MATPLOTLIB

# %%
dataset.plot(x="Hours", y="Scores", style="o", markerfacecolor="yellow", markeredgecolor="black")
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Scored')
plt.title('Hours Studied Vs Percentage Scores Of Students')
plt.grid(True, linestyle='-', color="green")
plt.show()

# %% [markdown]
# TRAING THE DATA WITH TRAIN TEST MODEL SELECTION

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size= 0.20, random_state= 0)
print("X test shape " + str(X_test.shape))
print("y test shape " + str(y_test.shape))
# Out:
# X test shape (5, 1)
# y test shape (5, 1)

# %% [markdown]
# GETTING A LINEAR REGRESSION LINE WITHIN THE DATA AND VISUALIZING IT

# %%
model = LinearRegression()
model.fit(x, y)
reg_line = model.coef_ * x + model.intercept_
plt.scatter(x, y)
plt.plot(x, reg_line)
plt.show()

# %% [markdown]
# DATA PREDICTION AND VISUALIZING THE ACTUAL AND PREDICTED VALUES

# %%
y_pred = model.predict(X_test)
print("Training score", model.score(X_train, y_train))
print("Testing score", model.score(X_test, y_test))
dataset.plot(kind='bar', figsize=(6, 6))
plt.title("Comapring actual and predicted scores and hours")
plt.show()
# Out:
# Training score 0.9512837351709387
# Testing score 0.9491748734859172

# %% [markdown]
# FINALLY, PUTTING 9.25 HOURS OF STUDY TO PREDICT THE SCORES OF THE STUDENT

# %%
hours = 9.25
test = np.array(hours).reshape(-1, 1)
predicter = model.predict(test)
print("Hours Given ", hours)
print("Predicted score of a student ", predicter[0])
# Out:
# Hours Given  9.25
# Predicted score of a student  [92.90985477]
